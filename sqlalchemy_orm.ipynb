# %% [markdown]
# ## Learning Outcomes:
#
# 1. Connecting to our database using SQLAlchemy
# 1. SQLite
# 1. The SQLAlchemy ORM
# 1. Working with the Session object

# %%
# Prerequisites - Install SQLAlchemy
# %pip install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.0.44)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from SQLAlchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Required imports
from sqlalchemy import create_engine, text
connection_string = "sqlite:///orm1.db"
engine = create_engine(connection_string, echo=True)

# %% [markdown]
# # Object-relational mapping (ORM)

# %% [markdown]
# Typically, when working with Python, we prefer to work with objects rather than rows in a database table.
#
# This is where the idea of ORM comes in. ORM stands for Object-Relational Mapping. It's a technique whereby we can define Python classes called "models" that are mapped to database tables.
#
# When using an ORM, such as SQLAlchemy, we can work with these Python objects, called "model instances", and have each correspond to a row.
#
# The ORM will then help us translate our Python operations into the appropriate SQL queries.

# %%
# To work with the ORM, we need some additional imports
from sqlalchemy import ForeignKey, Integer, String
from sqlalchemy.orm import Session, declarative_base, mapped_column, relationship

# %%
# We then need to create a base class for our models to inherit from

Base = declarative_base()

# %%
# Let us start with a very simple class - a Car
class Car(Base):
    __tablename__ = "car" # The name of the table in the DB
    id = mapped_column(Integer, primary_key=True)
    model = mapped_column(String(30), nullable=False)
    year = mapped_column(Integer, nullable=False)
    colour = mapped_column(String(30))

    def __str__(self):
        return f"A {self.colour} {self.year} {self.model}"

# Note that it's a regular Python class, but with class-level attributes that describe the columns.
# Each column then is an instance of a SQLAlchemy type, which is a Python class that represents a DB type.

# The basic types are documented in:
# https://docs.sqlalchemy.org/en/20/core/type_basics.html#generic-camelcase-types

# %%
# The table won't be created yet. To create it, we need to run:
Base.metadata.create_all(engine)
# Out:
# 2025-12-01 15:09:07,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-01 15:09:07,065 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("car")
# 2025-12-01 15:09:07,066 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-01 15:09:07,067 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("car")
# 2025-12-01 15:09:07,068 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-01 15:09:07,069 INFO sqlalchemy.engine.Engine
# CREATE TABLE car (
# 	id INTEGER NOT NULL,
# 	model VARCHAR(30) NOT NULL,
# 	year INTEGER NOT NULL,
# 	colour VARCHAR(30),
# 	PRIMARY KEY (id)
# )
#
#
# 2025-12-01 15:09:07,071 INFO sqlalchemy.engine.Engine [no key 0.00161s] ()
# 2025-12-01 15:09:07,076 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import create_engine, text
connection_string = "sqlite:///orm2.db"
engine = create_engine(connection_string, echo=True)

from sqlalchemy import Integer, String, ForeignKey
from sqlalchemy.orm import Session, DeclarativeBase, Mapped, mapped_column, relationship

class Base(DeclarativeBase):
    pass

class Owner(Base):
    __tablename__ = "owner"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str] = mapped_column(String(50), nullable=False)

    #one-to-many relationship
    cars: Mapped[list["Car"]] = relationship(
        back_populates="owner", # link to Car.owner
        cascade="all, delete-orphan"
    )

    def __str__(self) -> str:
        return self.name


class Car(Base):
    __tablename__ = "car"
    id: Mapped[int] = mapped_column(primary_key=True)
    model: Mapped[str] = mapped_column(String(30), nullable=False)
    year: Mapped[int] = mapped_column(nullable=False)
    colour: Mapped[str | None] = mapped_column(String(30))
    owner_id: Mapped[int] = mapped_column(ForeignKey("owner.id"))

    #link back to Owner
    owner: Mapped["Owner"] = relationship(back_populates="cars") # link to owner.cars

    def __str__(self) -> str:
        return f"{self.id}, {self.model}, {self.year}, {self.colour}, {self.owner_id}, {self.owner}"

Base.metadata.create_all(engine)
# Out:
# 2025-12-01 15:09:14,053 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-01 15:09:14,054 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("owner")
# 2025-12-01 15:09:14,056 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-01 15:09:14,058 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("owner")
# 2025-12-01 15:09:14,060 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-01 15:09:14,062 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("car")
# 2025-12-01 15:09:14,062 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-01 15:09:14,063 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("car")
# 2025-12-01 15:09:14,064 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-01 15:09:14,065 INFO sqlalchemy.engine.Engine
# CREATE TABLE owner (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-12-01 15:09:14,067 INFO sqlalchemy.engine.Engine [no key 0.00166s] ()
# 2025-12-01 15:09:14,076 INFO sqlalchemy.engine.Engine
# CREATE TABLE car (
# 	id INTEGER NOT NULL,
# 	model VARCHAR(30) NOT NULL,
# 	year INTEGER NOT NULL,
# 	colour VARCHAR(30),
# 	owner_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(owner_id) REFERENCES owner (id)
# )
#
#
# 2025-12-01 15:09:14,079 INFO sqlalchemy.engine.Engine [no key 0.00340s] ()
# 2025-12-01 15:09:14,092 INFO sqlalchemy.engine.Engine COMMIT

# %%
# let us create some owners objects
anand = Owner(name="Anand")
dan = Owner(name="Daniel")
print(anand)
print(dan)
# Out:
# Anand
# Daniel

# %% [markdown]
# # SQLAlchemy Sessions
#
# SQLAlchemy's ORM includes a session management system that handles the interactions between your Python objects and the database.
#
# A session is a higher-level abstraction than a connection, and it's the recommended way to interact with the database when using the ORM. Sessions allow us to combine multiple operations into a single transaction, and they also provide a way to keep track of changes to objects.

# %%
# store the owner objects in the table
with Session(engine) as session:
    session.add(anand)
    session.add(dan)
    session.commit()
# Out:
# 2025-12-01 15:16:29,569 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-01 15:16:29,573 INFO sqlalchemy.engine.Engine INSERT INTO owner (name) VALUES (?) RETURNING id
# 2025-12-01 15:16:29,574 INFO sqlalchemy.engine.Engine [generated in 0.00012s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Anand',)
# 2025-12-01 15:16:29,575 INFO sqlalchemy.engine.Engine INSERT INTO owner (name) VALUES (?) RETURNING id
# 2025-12-01 15:16:29,575 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('Daniel',)
# 2025-12-01 15:16:29,576 INFO sqlalchemy.engine.Engine COMMIT

# %%
# check that the owner objects were added to the table
with Session(engine) as session:
    owners = session.query(Owner).all()

for owner in owners:
    print(owner)
# Out:
# 2025-12-01 15:16:55,196 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-01 15:16:55,200 INFO sqlalchemy.engine.Engine SELECT owner.id AS owner_id, owner.name AS owner_name
# FROM owner
# 2025-12-01 15:16:55,201 INFO sqlalchemy.engine.Engine [generated in 0.00240s] ()
# 2025-12-01 15:16:55,202 INFO sqlalchemy.engine.Engine ROLLBACK
# Anand
# Daniel

# %%
# let us create some car objects
car1 = Car(model="Ford", year=2009, colour="Sea grey", owner=owners[0])
car2 = Car(model="Tesla", year=2020, colour="Red", owner=owners[1])
print(car1)
print(car2)
# Out:
# None, Ford, 2009, Sea grey, None, Anand
# None, Tesla, 2020, Red, None, Daniel

# %%
# let us add cars to the owners
with Session(engine) as session:
    session.add(car1)
    session.add(car2)
    session.commit()
# Out:
# 2025-12-01 15:17:20,645 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-01 15:17:20,649 INFO sqlalchemy.engine.Engine INSERT INTO car (model, year, colour, owner_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-12-01 15:17:20,652 INFO sqlalchemy.engine.Engine [generated in 0.00016s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Ford', 2009, 'Sea grey', 1)
# 2025-12-01 15:17:20,653 INFO sqlalchemy.engine.Engine INSERT INTO car (model, year, colour, owner_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-12-01 15:17:20,655 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('Tesla', 2020, 'Red', 2)
# 2025-12-01 15:17:20,656 INFO sqlalchemy.engine.Engine COMMIT

# %%
engine.echo = False
# let us check if the cars were added to the database
with Session(engine) as session:
    cars = session.query(Car).all()
    for car in cars:
        print(car)
# Out:
# 1, Ford, 2009, Sea grey, 1, Anand
# 2, Tesla, 2020, Red, 2, Daniel

# %%
engine.echo = False
# add more objects
car3 = Car(model="Citreon", year=2023, colour="green", owner=owners[0])
car4 = Car(model="Volkswagon", year=2024, colour="maroon", owner=owners[1])
with Session(engine) as session:    
    session.add(car3)
    session.add(car4)
    session.commit()

# %%
# get all the cars that belong to an owner
with Session(engine) as session:
    anand = session.get(Owner, 1) # Get owner with pk=1    
    # get anand's cars
    print("Anand's cars: ")
    for car in anand.cars:
        print(car)
    
    dan = session.get(Owner, 2)
    # get dan's cars
    print("Dan's cars: ")
    for car in dan.cars:
        print(car)
# Out:
# Anand's cars:
# 1, Ford, 2009, Sea grey, 1, Anand
# 3, Citreon, 2023, green, 1, Anand
# Dan's cars:
# 2, Tesla, 2020, Red, 2, Daniel
# 4, Volkswagon, 2024, maroon, 2, Daniel

# %%
# now given a car get its owner
with Session(engine) as session:
    car1 = session.get(Car, 1)
    print(car1.owner)

    car2 = session.get(Car, 2)
    print(car2.owner)
# Out:
# Anand
# Daniel

# %%
# Optional command only required if you wanted to delete the sqlite db file
engine.dispose()
